# %%
import sys
import os

from value import  Value

# %%
a = Value(1)
b= Value(2)
c= Value(3)

# %%
d = a+b+c

# %%
def f(x_val):
    x = Value(x_val)
    return (x**3) + (Value(2.0)*x)

# %%
x = 2.0
h=0.01

# %%
true_slp = 14.0

# %%
f_x_plus_h = f(x+h).data# why are we calling .data adn what is it 
f_x = f(x).data

# %%
f_x
# Out:
# 12.0

# %%
f_x_plus_h
# Out:
# 12.140600999999997

# %%
type(f_x)
# Out:
# float

# %%
forward_diff = (f_x_plus_h - f_x )/h 
forward_err = abs(true_slp - forward_diff) # we calculated the true slp with the derivative formula

# %%
forward_diff
# Out:
# 14.060099999999665

# %%
forward_err
# Out:
# 0.06009999999966453
